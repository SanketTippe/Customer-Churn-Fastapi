# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
data=pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
data.shape
# Out:
# (7043, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# drop the customer id becaues it's not necessary
data.drop('customerID',axis=1,inplace=True)

# %%
data
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
data.columns #return all columns name
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data['gender'].value_counts()#finding male and female
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
data['gender'].value_counts().plot.bar()# ploting bar for gender with value count
# Out:
# <Axes: xlabel='gender'>

# %%
data['SeniorCitizen'].unique()# finding unique values
data['SeniorCitizen'].value_counts()# for finding value of 0 and 1
# Out:
# SeniorCitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64

# %%
for col in data.columns:
    if data[col].dtype =='object':
        print(col,data[col].unique())
        print(60*'*')
# Out:
# gender ['Female' 'Male']
# ************************************************************
# Partner ['Yes' 'No']
# ************************************************************
# Dependents ['No' 'Yes']
# ************************************************************
# PhoneService ['No' 'Yes']
# ************************************************************
# MultipleLines ['No phone service' 'No' 'Yes']
# ************************************************************
# InternetService ['DSL' 'Fiber optic' 'No']
# ************************************************************
# OnlineSecurity ['No' 'Yes' 'No internet service']
# ************************************************************
# OnlineBackup ['Yes' 'No' 'No internet service']
# ************************************************************
# DeviceProtection ['No' 'Yes' 'No internet service']
# ************************************************************
# TechSupport ['No' 'Yes' 'No internet service']
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
#Checking null values
data.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
for col in ['tenure','MonthlyCharges','TotalCharges']:
    print(col,len(data[data[col]==" "]))
    print("*"*60)
# Out:
# tenure 0
# ************************************************************
# MonthlyCharges 0
# ************************************************************
# TotalCharges 11
# ************************************************************

# %%
# there are some missing values present in our TotalCharges 
#replacing " " values with 0.0  
data['TotalCharges']=data['TotalCharges'].replace({" ":"0.0"}).astype(float)

# %%
for col in ['tenure','MonthlyCharges','TotalCharges']:
    print(col,len(data[data[col]==" "]))
    print("*"*60)
# Out:
# tenure 0
# ************************************************************
# MonthlyCharges 0
# ************************************************************
# TotalCharges 0
# ************************************************************

# %%
data['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# ## EDA-Exploratory Data Analysis

# %%
data.shape
# Out:
# (7043, 20)

# %%
data.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data.describe().T  # here T means Transpose
# Out:
#                  count         mean          std    min     25%      50%  \
# SeniorCitizen   7043.0     0.162147     0.368612   0.00    0.00     0.00
# tenure          7043.0    32.371149    24.559481   0.00    9.00    29.00
# MonthlyCharges  7043.0    64.761692    30.090047  18.25   35.50    70.35
# TotalCharges    7043.0  2279.734304  2266.794470   0.00  398.55  1394.55
#
#                     75%      max
# SeniorCitizen      0.00     1.00
# tenure            55.00    72.00
# MonthlyCharges    89.85   118.75
# TotalCharges    3786.60  8684.80

# %%
def plot_distribution(data,column_name):
    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    sns.histplot(data[column_name])
    plt.title(f"Distribution of {column_name}")

    column_mean=data[column_name].mean()
    column_median=data[column_name].median()
    plt.axvline(column_mean,color="red",linestyle="--",label="Mean")
    plt.axvline(column_median,color="red",linestyle="--",label="Median")
    plt.subplot(1,2,2)
    plt.legend()
    sns.boxplot(y=data[column_name])
    plt.title(f"Box of {column_name}")

# %%
plot_distribution(data,"tenure")
# Out:
# C:\Users\Sanket Tippe\AppData\Local\Temp\ipykernel_17816\489818874.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plot_distribution(data,"MonthlyCharges")
# Out:
# C:\Users\Sanket Tippe\AppData\Local\Temp\ipykernel_17816\489818874.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plot_distribution(data,"TotalCharges")
# Out:
# C:\Users\Sanket Tippe\AppData\Local\Temp\ipykernel_17816\489818874.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(8,4))
sns.heatmap(data[['tenure','MonthlyCharges','TotalCharges']].corr(),annot=True,cmap='coolwarm',fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
categorical_column=data.select_dtypes(include="object").columns.to_list()+['SeniorCitizen']
for col in categorical_column:
    plt.figure(figsize=(6,4))
    sns.countplot(x=data[col])
    # sns.countplot(data=data,x=col,hue="Churn")
    plt.title(f"{col}Distribution by Churn")
    plt.show(0)

# %%
# label encoding 
data['Churn']=data['Churn'].replace({'Yes':1,'No':0})

# %%
data['Churn']
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 7043, dtype: int64

# %%
object_columns=data.select_dtypes(include="object").columns

# %%
object_columns
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

encoder={}

for column in object_columns:
    le=LabelEncoder()
    data[column]=le.fit_transform(data[column]).astype(int)
    encoder[column]=le

# %%
encoder
# Out:
# {'gender': LabelEncoder(),
#  'Partner': LabelEncoder(),
#  'Dependents': LabelEncoder(),
#  'PhoneService': LabelEncoder(),
#  'MultipleLines': LabelEncoder(),
#  'InternetService': LabelEncoder(),
#  'OnlineSecurity': LabelEncoder(),
#  'OnlineBackup': LabelEncoder(),
#  'DeviceProtection': LabelEncoder(),
#  'TechSupport': LabelEncoder(),
#  'StreamingTV': LabelEncoder(),
#  'StreamingMovies': LabelEncoder(),
#  'Contract': LabelEncoder(),
#  'PaperlessBilling': LabelEncoder(),
#  'PaymentMethod': LabelEncoder()}

# %%
import pickle
with open("encoder.pkl","wb") as f:
    pickle.dump(encoder,f)

# %%
from sklearn.preprocessing import StandardScaler
numerical_column=['tenure','MonthlyCharges','TotalCharges']
scaler=StandardScaler()
data[numerical_column]=scaler.fit_transform(data[numerical_column])

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import r2_score,roc_auc_score,accuracy_score,confusion_matrix
from sklearn.metrics import classification_report

# %%
x=data.drop('Churn',axis=1)

# %%
x
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 0          0              0        1           0 -1.277445             0
# 1          1              0        0           0  0.066327             1
# 2          1              0        0           0 -1.236724             1
# 3          1              0        0           0  0.514251             0
# 4          0              0        0           0 -1.236724             1
# ...      ...            ...      ...         ...       ...           ...
# 7038       1              0        1           1 -0.340876             1
# 7039       0              0        1           1  1.613701             1
# 7040       0              0        1           1 -0.870241             0
# 7041       1              1        1           0 -1.155283             1
# 7042       1              0        0           0  1.369379             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
y=data['Churn']
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 7043, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
y_train.value_counts()
# Out:
# Churn
# 0    4138
# 1    1496
# Name: count, dtype: int64

# %%
smote=SMOTE(random_state=42)

# %%
smote
# Out:
# SMOTE(random_state=42)

# %%
x_train_smote,y_train_smote=smote.fit_resample(x_train,y_train)

# %%
y_train_smote
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 8271    1
# 8272    1
# 8273    1
# 8274    1
# 8275    1
# Name: Churn, Length: 8276, dtype: int64

# %%
models={
    "Random Forest":RandomForestClassifier(random_state=42),
    "XGBoost":XGBClassifier(random_state=42)
    
}

# %%
hyperparameters={"Random Forest":{"n_estimators":[50,100,200],
                                   "max_depth":[5,10,None],
                                 },
                 "XGBoost":{"Learning_Rate":[0.01,0.1,0.2],
                  "max_depth":[3,5,7],
}
}

# %%
best_models={}
for model_name,model in models.items():
    print(f"Tunning {model_name}...........")
    grid=GridSearchCV(estimator=model,param_grid=hyperparameters[model_name],cv=3,scoring="accuracy")
    grid.fit(x_train_smote,y_train_smote)
    best_models=[model_name]=grid.best_estimator_
    print(f"Best Parameter for {model_name}:{grid.best_params_}")
    print(f"Best Accuracy for {model_name}:{grid.best_score_:.2f}\n")
# Out:
# Tunning Random Forest...........

# %%
best_models = {}
for model_name, model in models.items():
    print(f"Tuning {model_name}...........")
    grid = GridSearchCV(estimator=model, param_grid=hyperparameters[model_name], cv=3, scoring="accuracy")
    grid.fit(x_train_smote, y_train_smote)
    
    # FIX: Use brackets to assign the value to the key
    best_models[model_name] = grid.best_estimator_ 
    
    print(f"Best Parameter for {model_name}: {grid.best_params_}")
    print(f"Best Accuracy for {model_name}: {grid.best_score_:.2f}\n")

# %%
with open("best_model.pkl","wb") as f:
    pickle.dump(best_models['Random Forest'],f)

# %%
with open("Scler.pkl","wb") as f:
    pickle.dump(scaler,f)

# %%
y_test_pred=best_models['Random Forest'].predict(x_test)
y_test_prob=best_models['Random Forest'].predict_proba(x_test)[:,1]

# %%
y_test_pred

# %%
y_test_prob

# %%
print(f"Accuracy: ", accuracy_score(y_test,y_test_pred))
print(f"ROC AUC Score: " ,roc_auc_score(y_test,y_test_pred))
print(f"Confusion Matrix: \n" ,confusion_matrix(y_test,y_test_pred))
print(f"Classification Report: \n" ,classification_report(y_test,y_test_pred))

# %%
with open("best_model.pkl","rb") as f:
    loaded_model=pickle.load(f)
with open("encoder.pkl","rb") as f:
    encoders=pickle.load(f)
with open("Scler.pkl","rb") as f:
    Scler_data=pickle.load(f)

# %%
def make_prediction(input_data):
    input_df=pd.DataFrame([input_data])
    for col,encoder in encoders.items():
        input_df[col]=encoder.transform(input_df[col])
    numerical_cols=['tenure','MonthlyCharges','TotalCharges']
    input_df[numerical_cols]=Scler_data.transform(input_df[numerical_cols])
    predication=loaded_model.predict(input_df)[0]
    probability=loaded_model.predict_proba(input_df)[0,1]
    return "Churn" if predication==1 else "No Churn",probability

# %%
data.columns

# %%
eg={'gender':'Female',
    'SeniorCitizen':0,
    'Partner':'Yes',
    'Dependents':'No',
    'tenure':1,
    'PhoneService':'No',
    'MultipleLines':'No phone service',
    'InternetService':'DSL',
    'OnlineSecurity':'No',
    'OnlineBackup':'Yes',
    'DeviceProtection':'No',
    'TechSupport':'No',
    'StreamingTV':'No',
    'StreamingMovies':'No',
    'Contract':'Month-to-month',
    'PaperlessBilling':'Yes',
    'PaymentMethod':'Electronic check',
    'MonthlyCharges':29.85,
    'TotalCharges':29.85
    
   }

# %%
predication,prob=make_prediction(eg)
predication

# %%
print(f"Predication :{predication}\nProbability:{prob:.2f}")

# %%
# Flask Framwork web application
